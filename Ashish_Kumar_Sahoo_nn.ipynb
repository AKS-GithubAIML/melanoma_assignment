# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166b
# Out:
# Mounted at /content/gdrive

# %%
train_drive = "/content/gdrive/My Drive/Modeling With Colab/melanoma_assignment/Train"
test_drive = "/content/gdrive/My Drive/Modeling With Colab/melanoma_assignment/Test"

# %%
# !ls "/content/gdrive/My Drive/Modeling With Colab/melanoma_assignment/Test"
# Out:
# 'actinic keratosis'	 melanoma		      'seborrheic keratosis'
# 'basal cell carcinoma'	 nevus			      'squamous cell carcinoma'
#  dermatofibroma		'pigmented benign keratosis'  'vascular lesion'

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPool2D, Input
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping

# convert to one-hot-encoding
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path(train_drive)
data_dir_test = pathlib.Path(test_drive)

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
## Write your test dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here

num_classes = 9 # As target class has 9 labels

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3989801 (15.22 MB)
# Trainable params: 3989801 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
# Training with 20 Epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 8s 148ms/step - loss: 2.0441 - accuracy: 0.2455 - val_loss: 1.8087 - val_accuracy: 0.3154
# Epoch 2/20
# 56/56 [==============================] - 8s 134ms/step - loss: 1.7023 - accuracy: 0.3912 - val_loss: 1.8817 - val_accuracy: 0.3311
# Epoch 3/20
# 56/56 [==============================] - 8s 134ms/step - loss: 1.4931 - accuracy: 0.4821 - val_loss: 1.4624 - val_accuracy: 0.5324
# Epoch 4/20
# 56/56 [==============================] - 8s 135ms/step - loss: 1.3339 - accuracy: 0.5352 - val_loss: 1.3870 - val_accuracy: 0.5503
# Epoch 5/20
# 56/56 [==============================] - 8s 135ms/step - loss: 1.2915 - accuracy: 0.5558 - val_loss: 1.4038 - val_accuracy: 0.5459
# Epoch 6/20
# 56/56 [==============================] - 8s 138ms/step - loss: 1.1974 - accuracy: 0.5731 - val_loss: 1.3629 - val_accuracy: 0.5615
# Epoch 7/20
# 56/56 [==============================] - 8s 138ms/step - loss: 1.1393 - accuracy: 0.6004 - val_loss: 1.3790 - val_accuracy: 0.5213
# Epoch 8/20
# 56/56 [==============================] - 8s 139ms/step - loss: 1.0659 - accuracy: 0.6222 - val_loss: 1.4202 - val_accuracy: 0.5213
# Epoch 9/20
# 56/56 [==============================] - 8s 140ms/step - loss: 0.9706 - accuracy: 0.6540 - val_loss: 1.5213 - val_accuracy: 0.5145
# Epoch 10/20
# 56/56 [==============================] - 8s 140ms/step - loss: 1.0644 - accuracy: 0.6295 - val_loss: 1.5532 - val_accuracy: 0.5391
# Epoch 11/20
# 56/56 [==============================] - 8s 142ms/step - loss: 0.8698 - accuracy: 0.7015 - val_loss: 1.6662 - val_accuracy: 0.5302
# Epoch 12/20
# 56/56 [==============================] - 8s 140ms/step - loss: 0.8088 - accuracy: 0.7109 - val_loss: 1.6948 - val_accuracy: 0.5190
# Epoch 13/20
# 56/56 [==============================] - 8s 143ms/step - loss: 0.7114 - accuracy: 0.7433 - val_loss: 1.6621 - val_accuracy: 0.5839
# Epoch 14/20
# 56/56 [==============================] - 8s 144ms/step - loss: 0.6900 - accuracy: 0.7467 - val_loss: 1.6580 - val_accuracy: 0.5570
# Epoch 15/20
# 56/56 [==============================] - 8s 146ms/step - loss: 0.6565 - accuracy: 0.7701 - val_loss: 1.7952 - val_accuracy: 0.5391
# Epoch 16/20
# 56/56 [==============================] - 8s 145ms/step - loss: 0.5417 - accuracy: 0.7997 - val_loss: 1.8429 - val_accuracy: 0.5481
# Epoch 17/20
# 56/56 [==============================] - 8s 148ms/step - loss: 0.4741 - accuracy: 0.8337 - val_loss: 1.8345 - val_accuracy: 0.5615
# Epoch 18/20
# 56/56 [==============================] - 33s 600ms/step - loss: 0.4118 - accuracy: 0.8510 - val_loss: 1.8357 - val_accuracy: 0.5391
# Epoch 19/20
# 56/56 [==============================] - 53s 967ms/step - loss: 0.4391 - accuracy: 0.8382 - val_loss: 1.9130 - val_accuracy: 0.5749
# Epoch 20/20
# 56/56 [==============================] - 8s 141ms/step - loss: 0.3620 - accuracy: 0.8599 - val_loss: 2.4123 - val_accuracy: 0.5526

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# *   There is a disimilarirty between Training and Validation Accuracy
# *   Trainging Model is clearly overfitting
# *   Also Validation loss is not decresing significantly like Training Loss
# *   We can use Augumentation strategy to fix overfitting problem by using below
#
#             1.   horizontal flip
#             2.   random rotation
#             3.   random zoom in etc.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here

data_augmentation = keras.Sequential([
                                      layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
                                      layers.experimental.preprocessing.RandomRotation(0.1),
                                      layers.experimental.preprocessing.RandomZoom(0.1),
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes )
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 9s 151ms/step - loss: 1.9581 - accuracy: 0.2812 - val_loss: 1.7225 - val_accuracy: 0.3691
# Epoch 2/20
# 56/56 [==============================] - 8s 147ms/step - loss: 1.6872 - accuracy: 0.3728 - val_loss: 1.5937 - val_accuracy: 0.4653
# Epoch 3/20
# 56/56 [==============================] - 8s 149ms/step - loss: 1.5039 - accuracy: 0.4710 - val_loss: 1.5115 - val_accuracy: 0.4922
# Epoch 4/20
# 56/56 [==============================] - 8s 149ms/step - loss: 1.4319 - accuracy: 0.5106 - val_loss: 1.5216 - val_accuracy: 0.4743
# Epoch 5/20
# 56/56 [==============================] - 8s 151ms/step - loss: 1.3919 - accuracy: 0.5156 - val_loss: 1.3984 - val_accuracy: 0.5302
# Epoch 6/20
# 56/56 [==============================] - 8s 151ms/step - loss: 1.3572 - accuracy: 0.5318 - val_loss: 1.5146 - val_accuracy: 0.4966
# Epoch 7/20
# 56/56 [==============================] - 9s 153ms/step - loss: 1.2983 - accuracy: 0.5268 - val_loss: 1.4067 - val_accuracy: 0.5436
# Epoch 8/20
# 56/56 [==============================] - 9s 153ms/step - loss: 1.2531 - accuracy: 0.5580 - val_loss: 1.3662 - val_accuracy: 0.5280
# Epoch 9/20
# 56/56 [==============================] - 9s 155ms/step - loss: 1.2472 - accuracy: 0.5541 - val_loss: 1.2922 - val_accuracy: 0.5570
# Epoch 10/20
# 56/56 [==============================] - 9s 158ms/step - loss: 1.2103 - accuracy: 0.5675 - val_loss: 1.3813 - val_accuracy: 0.5391
# Epoch 11/20
# 56/56 [==============================] - 9s 162ms/step - loss: 1.1818 - accuracy: 0.5765 - val_loss: 1.3617 - val_accuracy: 0.5391
# Epoch 12/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.1774 - accuracy: 0.5748 - val_loss: 1.3954 - val_accuracy: 0.5548
# Epoch 13/20
# 56/56 [==============================] - 9s 158ms/step - loss: 1.1361 - accuracy: 0.5876 - val_loss: 1.3616 - val_accuracy: 0.5660
# Epoch 14/20
# 56/56 [==============================] - 9s 158ms/step - loss: 1.1400 - accuracy: 0.5859 - val_loss: 1.2778 - val_accuracy: 0.5615
# Epoch 15/20
# 56/56 [==============================] - 9s 169ms/step - loss: 1.0938 - accuracy: 0.6010 - val_loss: 1.3473 - val_accuracy: 0.5660
# Epoch 16/20
# 56/56 [==============================] - 9s 161ms/step - loss: 1.0939 - accuracy: 0.5982 - val_loss: 1.3569 - val_accuracy: 0.5817
# Epoch 17/20
# 56/56 [==============================] - 9s 162ms/step - loss: 1.0758 - accuracy: 0.6194 - val_loss: 1.3403 - val_accuracy: 0.5436
# Epoch 18/20
# 56/56 [==============================] - 9s 168ms/step - loss: 1.0567 - accuracy: 0.6155 - val_loss: 1.2910 - val_accuracy: 0.5570
# Epoch 19/20
# 56/56 [==============================] - 10s 178ms/step - loss: 1.0169 - accuracy: 0.6323 - val_loss: 1.2957 - val_accuracy: 0.5951
# Epoch 20/20
# 56/56 [==============================] - 10s 181ms/step - loss: 1.0005 - accuracy: 0.6350 - val_loss: 1.5157 - val_accuracy: 0.5213

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# *   Overfitting has been handeled by using Augumentation
# *   But it shows a class imbalance problem
# *   Accuracy is not upto the mark

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
from glob import glob
path_list = [ x for x in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]
lesion_list = [ os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]
print(len(lesion_list))
# Out:
# 2239

# %%
df_dict_original = dict(zip(path_list, lesion_list))
print(list(df_dict_original.items())[:2])
# Out:
# [('Train/melanoma/ISIC_0010550.jpg', 'melanoma'), ('Train/melanoma/ISIC_0011128.jpg', 'melanoma')]

# %%
original_df = pd.DataFrame(list(df_dict_original.items()), columns=['Path','Label'])
original_df.head()
# Out:
#                               Path     Label
# 0  Train/melanoma/ISIC_0010550.jpg  melanoma
# 1  Train/melanoma/ISIC_0011128.jpg  melanoma
# 2  Train/melanoma/ISIC_0010587.jpg  melanoma
# 3  Train/melanoma/ISIC_0010034.jpg  melanoma
# 4  Train/melanoma/ISIC_0000555.jpg  melanoma

# %%
original_df[['Label']].value_counts()
# Out:
# Label
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: count, dtype: int64

# %%
original_df[['Label']].value_counts(normalize=True)
# Out:
# Label
# pigmented benign keratosis    0.206342
# melanoma                      0.195623
# basal cell carcinoma          0.167932
# nevus                         0.159446
# squamous cell carcinoma       0.080840
# vascular lesion               0.062081
# actinic keratosis             0.050916
# dermatofibroma                0.042430
# seborrheic keratosis          0.034390
# Name: proportion, dtype: float64

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# *   'seborrheic keratosis' has the least number of samples 3.4% of total training data
# *   'pigmented benign keratosis' and 'melanoma' dominate the available training data with 20.6% and 19.5% respectively.

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.25.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset=str(data_dir_train) + '/'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x30392A250>: 100%|█|
# Initialised with 376 image(s) found.
# Output directory set to Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x303971290>: 100%|█|
# Initialised with 95 image(s) found.
# Output directory set to Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x177C398D0>: 100%|█|
# Initialised with 438 image(s) found.
# Output directory set to Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x3033CDD50>: 100%|█
# Initialised with 357 image(s) found.
# Output directory set to Train/nevus/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x3
# Initialised with 462 image(s) found.
# Output directory set to Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x177E83CD0>: 100%|█|
# Initialised with 77 image(s) found.
# Output directory set to Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x37305A890>: 100%|█
# Initialised with 181 image(s) found.
# Output directory set to Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x3
# Initialised with 139 image(s) found.
# Output directory set to Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x303277C50>: 100%|█|

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
# Convert the dictionary to a DataFrame
df2 = pd.DataFrame(list(dataframe_dict_new.items()), columns=['Path', 'Label'])

# Append df2 to original_df
new_df = pd.concat([original_df, df2], ignore_index=True)

# %%
new_df['Label'].value_counts()
# Out:
# Label
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: count, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
#data_dir_train="path to directory with training data + data created using augmentor"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
# Define early stopping callback
#early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1)
#callbacks=[early_stopping]
epochs = 30
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 30s 178ms/step - loss: 0.9119 - accuracy: 0.6658 - val_loss: 1.2460 - val_accuracy: 0.5731
# Epoch 2/30
# 169/169 [==============================] - 31s 184ms/step - loss: 0.9108 - accuracy: 0.6628 - val_loss: 2.3244 - val_accuracy: 0.3823
# Epoch 3/30
# 169/169 [==============================] - 32s 186ms/step - loss: 0.8634 - accuracy: 0.6754 - val_loss: 2.2044 - val_accuracy: 0.4900
# Epoch 4/30
# 169/169 [==============================] - 33s 192ms/step - loss: 0.8523 - accuracy: 0.6856 - val_loss: 3.4397 - val_accuracy: 0.3860
# Epoch 5/30
# 169/169 [==============================] - 33s 194ms/step - loss: 0.8214 - accuracy: 0.6932 - val_loss: 1.7948 - val_accuracy: 0.5085
# Epoch 6/30
# 169/169 [==============================] - 35s 205ms/step - loss: 0.8182 - accuracy: 0.6988 - val_loss: 1.4378 - val_accuracy: 0.5360
# Epoch 7/30
# 169/169 [==============================] - 41s 242ms/step - loss: 0.7746 - accuracy: 0.7114 - val_loss: 1.0818 - val_accuracy: 0.6236
# Epoch 8/30
# 169/169 [==============================] - 46s 269ms/step - loss: 0.7423 - accuracy: 0.7253 - val_loss: 1.4740 - val_accuracy: 0.5798
# Epoch 9/30
# 169/169 [==============================] - 45s 262ms/step - loss: 0.7516 - accuracy: 0.7239 - val_loss: 1.1770 - val_accuracy: 0.5887
# Epoch 10/30
# 169/169 [==============================] - 44s 255ms/step - loss: 0.7203 - accuracy: 0.7257 - val_loss: 1.7682 - val_accuracy: 0.4863
# Epoch 11/30
# 169/169 [==============================] - 45s 263ms/step - loss: 0.7114 - accuracy: 0.7344 - val_loss: 3.0590 - val_accuracy: 0.4469
# Epoch 12/30
# 169/169 [==============================] - 47s 275ms/step - loss: 0.6965 - accuracy: 0.7422 - val_loss: 1.4473 - val_accuracy: 0.5880
# Epoch 13/30
# 169/169 [==============================] - 46s 268ms/step - loss: 0.7013 - accuracy: 0.7400 - val_loss: 2.2078 - val_accuracy: 0.4491
# Epoch 14/30
# 169/169 [==============================] - 45s 263ms/step - loss: 0.7078 - accuracy: 0.7500 - val_loss: 1.1839 - val_accuracy: 0.6036
# Epoch 15/30
# 169/169 [==============================] - 46s 270ms/step - loss: 0.6957 - accuracy: 0.7494 - val_loss: 2.0837 - val_accuracy: 0.4469
# Epoch 16/30
# 169/169 [==============================] - 46s 268ms/step - loss: 0.6404 - accuracy: 0.7641 - val_loss: 1.5188 - val_accuracy: 0.5850
# Epoch 17/30
# 169/169 [==============================] - 47s 273ms/step - loss: 0.6320 - accuracy: 0.7665 - val_loss: 0.8625 - val_accuracy: 0.6934
# Epoch 18/30
# 169/169 [==============================] - 48s 278ms/step - loss: 0.6274 - accuracy: 0.7658 - val_loss: 1.1877 - val_accuracy: 0.5932
# Epoch 19/30
# 169/169 [==============================] - 47s 277ms/step - loss: 0.6552 - accuracy: 0.7634 - val_loss: 1.3038 - val_accuracy: 0.6214
# Epoch 20/30
# 169/169 [==============================] - 47s 277ms/step - loss: 0.6028 - accuracy: 0.7776 - val_loss: 0.7198 - val_accuracy: 0.7565
# Epoch 21/30
# 169/169 [==============================] - 47s 274ms/step - loss: 0.5860 - accuracy: 0.7845 - val_loss: 1.2464 - val_accuracy: 0.6043
# Epoch 22/30
# 169/169 [==============================] - 49s 285ms/step - loss: 0.5480 - accuracy: 0.7958 - val_loss: 1.0201 - val_accuracy: 0.6592
# Epoch 23/30
# 169/169 [==============================] - 47s 277ms/step - loss: 0.5751 - accuracy: 0.7806 - val_loss: 1.1467 - val_accuracy: 0.6162
# Epoch 24/30
# 169/169 [==============================] - 47s 276ms/step - loss: 0.5411 - accuracy: 0.7997 - val_loss: 0.8482 - val_accuracy: 0.7246
# Epoch 25/30
# 169/169 [==============================] - 49s 288ms/step - loss: 0.5359 - accuracy: 0.8064 - val_loss: 1.1727 - val_accuracy: 0.6578
# Epoch 26/30
# 169/169 [==============================] - 48s 282ms/step - loss: 0.5474 - accuracy: 0.7938 - val_loss: 1.9553 - val_accuracy: 0.5531
# Epoch 27/30
# 169/169 [==============================] - 48s 280ms/step - loss: 0.5449 - accuracy: 0.8001 - val_loss: 1.4694 - val_accuracy: 0.5843
# Epoch 28/30
# 169/169 [==============================] - 49s 286ms/step - loss: 0.5350 - accuracy: 0.8088 - val_loss: 1.2308 - val_accuracy: 0.6088
# Epoch 29/30
# 169/169 [==============================] - 49s 285ms/step - loss: 0.5020 - accuracy: 0.8101 - val_loss: 1.1347 - val_accuracy: 0.6637
# Epoch 30/30
# 169/169 [==============================] - 50s 292ms/step - loss: 0.5308 - accuracy: 0.8051 - val_loss: 1.1173 - val_accuracy: 0.6362

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:** Create your model (without batch normalization)

# %%
## your code goes here
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 32s 184ms/step - loss: 1.9230 - accuracy: 0.2737 - val_loss: 1.5654 - val_accuracy: 0.4120
# Epoch 2/30
# 169/169 [==============================] - 32s 190ms/step - loss: 1.4965 - accuracy: 0.4266 - val_loss: 1.3469 - val_accuracy: 0.4981
# Epoch 3/30
# 169/169 [==============================] - 33s 196ms/step - loss: 1.3627 - accuracy: 0.4842 - val_loss: 1.3098 - val_accuracy: 0.5033
# Epoch 4/30
# 169/169 [==============================] - 44s 260ms/step - loss: 1.2778 - accuracy: 0.5124 - val_loss: 1.2567 - val_accuracy: 0.5241
# Epoch 5/30
# 169/169 [==============================] - 60s 351ms/step - loss: 1.2630 - accuracy: 0.5260 - val_loss: 1.5593 - val_accuracy: 0.4469
# Epoch 6/30
# 169/169 [==============================] - 50s 292ms/step - loss: 1.1952 - accuracy: 0.5506 - val_loss: 1.1652 - val_accuracy: 0.5702
# Epoch 7/30
# 169/169 [==============================] - 48s 281ms/step - loss: 1.1242 - accuracy: 0.5734 - val_loss: 1.0596 - val_accuracy: 0.5909
# Epoch 8/30
# 169/169 [==============================] - 47s 275ms/step - loss: 1.1054 - accuracy: 0.5831 - val_loss: 1.1443 - val_accuracy: 0.5590
# Epoch 9/30
# 169/169 [==============================] - 47s 274ms/step - loss: 1.0573 - accuracy: 0.5987 - val_loss: 0.9951 - val_accuracy: 0.6102
# Epoch 10/30
# 169/169 [==============================] - 47s 274ms/step - loss: 1.0208 - accuracy: 0.6157 - val_loss: 1.0372 - val_accuracy: 0.5924
# Epoch 11/30
# 169/169 [==============================] - 46s 271ms/step - loss: 0.9746 - accuracy: 0.6421 - val_loss: 1.0247 - val_accuracy: 0.6214
# Epoch 12/30
# 169/169 [==============================] - 46s 271ms/step - loss: 0.9589 - accuracy: 0.6452 - val_loss: 1.0260 - val_accuracy: 0.6036
# Epoch 13/30
# 169/169 [==============================] - 46s 267ms/step - loss: 0.8875 - accuracy: 0.6673 - val_loss: 0.8791 - val_accuracy: 0.6704
# Epoch 14/30
# 169/169 [==============================] - 43s 249ms/step - loss: 0.8545 - accuracy: 0.6845 - val_loss: 0.9699 - val_accuracy: 0.6355
# Epoch 15/30
# 169/169 [==============================] - 48s 280ms/step - loss: 0.8523 - accuracy: 0.6858 - val_loss: 0.8945 - val_accuracy: 0.6644
# Epoch 16/30
# 169/169 [==============================] - 60s 353ms/step - loss: 0.7897 - accuracy: 0.7081 - val_loss: 0.8362 - val_accuracy: 0.6971
# Epoch 17/30
# 169/169 [==============================] - 50s 294ms/step - loss: 0.7879 - accuracy: 0.7116 - val_loss: 0.8313 - val_accuracy: 0.7053
# Epoch 18/30
# 169/169 [==============================] - 50s 295ms/step - loss: 0.7599 - accuracy: 0.7201 - val_loss: 0.8230 - val_accuracy: 0.6904
# Epoch 19/30
# 169/169 [==============================] - 49s 288ms/step - loss: 0.7308 - accuracy: 0.7276 - val_loss: 0.8101 - val_accuracy: 0.6941
# Epoch 20/30
# 169/169 [==============================] - 49s 286ms/step - loss: 0.6872 - accuracy: 0.7506 - val_loss: 0.7467 - val_accuracy: 0.7238
# Epoch 21/30
# 169/169 [==============================] - 47s 273ms/step - loss: 0.6998 - accuracy: 0.7418 - val_loss: 0.8315 - val_accuracy: 0.7023
# Epoch 22/30
# 169/169 [==============================] - 47s 275ms/step - loss: 0.7266 - accuracy: 0.7363 - val_loss: 0.7033 - val_accuracy: 0.7372
# Epoch 23/30
# 169/169 [==============================] - 49s 286ms/step - loss: 0.6363 - accuracy: 0.7697 - val_loss: 0.7480 - val_accuracy: 0.7231
# Epoch 24/30
# 169/169 [==============================] - 51s 296ms/step - loss: 0.6111 - accuracy: 0.7750 - val_loss: 0.7666 - val_accuracy: 0.7387
# Epoch 25/30
# 169/169 [==============================] - 53s 308ms/step - loss: 0.6254 - accuracy: 0.7756 - val_loss: 0.6650 - val_accuracy: 0.7491
# Epoch 26/30
# 169/169 [==============================] - 50s 294ms/step - loss: 0.5776 - accuracy: 0.7912 - val_loss: 0.7494 - val_accuracy: 0.7275
# Epoch 27/30
# 169/169 [==============================] - 48s 281ms/step - loss: 0.5754 - accuracy: 0.7888 - val_loss: 0.7523 - val_accuracy: 0.7313
# Epoch 28/30
# 169/169 [==============================] - 48s 282ms/step - loss: 0.5385 - accuracy: 0.8030 - val_loss: 0.6255 - val_accuracy: 0.7788
# Epoch 29/30
# 169/169 [==============================] - 50s 294ms/step - loss: 0.5215 - accuracy: 0.8075 - val_loss: 0.6535 - val_accuracy: 0.7498
# Epoch 30/30
# 169/169 [==============================] - 52s 301ms/step - loss: 0.5087 - accuracy: 0.8110 - val_loss: 0.7041 - val_accuracy: 0.7595

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# # Final Observation:
#
# 1.   We have handled Overfitting, Underfitting and Class Imbalance issues
# 2.   Last model without batchnormalization has Training Accuracy goes above 80% and Validation Accuracy goes above 75%
# 3.   With batch normalization train was not much help at it has more flctuation in Validation accuracy and Loss
